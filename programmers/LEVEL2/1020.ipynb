# %%
def dfs(v):
    visited[v] = 1
    for i in range(1, n + 1):
        if not visited[i] and graph[v][i]:
            dfs(i)


n, m = map(int, input().split())
graph = [[0] * (n + 1) for _ in range(n + 1)]
visited =[0] * (n + 1)

for _ in range(m):
    i, j = map(int, input().split())
    graph[i][j] = 1
    graph[j][i] = 1
    
cnt = 0   
for i in range(1, n + 1):

    if not visited[i]:
        dfs(i)
        cnt += 1
print(cnt)
# Out:
# 6 5
# 1 2
# 2 5
# 5 1
# 3 4
# 4 6
# 2

# %%
def dfs(v):
    visited[v] = 1
    for i in graph[v]:
        if not visited[i]:
            dfs(i)

n, m = map(int, input().split())
graph = [[0] * (n + 1) for _ in range(n + 1)]
visited =[0] * (n + 1)

for _ in range(m):
    i, j = map(int, input().split())
    graph[i].append(j)
    graph[j].append(i)

cnt = 0
for i in range(1, n + 1):
    if not visited[i]:
        dfs(i)
        cnt += 1
        
print(cnt)
# Out:
# 6 5
# 1 2
# 2 5
# 5 1
# 3 4
# 4 6
# 2

# %%
from collections import deque

def bfs(v):
    queue = deque()
    queue.append(v)
    visited[v] = 1
    
    while queue:
        v = queue.popleft()
        for i in graph[v]:
            if visited[i] == 0:
                visited[i] = -visited[v]
                queue.append(i)
            else:
                if visited[v] == visited[i]:
                    return False
    return True
            
                
    

for i in range(int(input())):
    n, m = map(int, input().split())
    graph = [[] for _ in range(n + 1)]
    visited = [0] * (n + 1)
    status = 1
    for _ in range(m):
        x, y = map(int, input().split())
        graph[x].append(y)
        graph[y].append(x)
        
    for k in range(1, n + 1):
        if visited[k] == 0:
            if not bfs(k):
                status = -1
                break
    print('YES' if status == 1 else 'NO')
# Out:
# 2
# 3 2
# 1 3
# 2 3
# YES
# 4 4
# 1 2
# 2 3
# 3 4
# 4 2
# NO

# %%
from collections import deque

def bfs(v):
    visited[v] = 1
    queue = deque()
    queue.append(v)
    
    while queue:
        v = queue.popleft()
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = 1

for i in range(int(input())):
    num = int(input())
    node = list(map(int, input().split()))
    graph = [[] for _ in range(num + 1)]
    visited = [0] * (num + 1)
    
    for i, v in enumerate(node):
        graph[i + 1].append(v)

cnt = 0
for i in range(1, num + 1):
    if not visited[i]:
        bfs(i)
        cnt += 1
print(cnt)
# Out:
# 1
# 10
# 2 1 3 4 5 6 7 9 10 8
# 7

# %%
from collections import deque

def solution(numbers, target):
    answer = 0
    queue = deque()
    n = len(numbers)
    queue.append([numbers[0],0])
    queue.append([-1*numbers[0],0])
    print(queue)
    while queue:
        temp, idx = queue.popleft()
        idx += 1
        if idx < n:
            queue.append([temp+numbers[idx], idx])
            queue.append([temp-numbers[idx], idx])
        else:
            if temp == target:
                answer += 1
        print(queue)
        print()
    return answer

solution([1, 1, 1, 1, 1], 3)
# Out:
# deque([[1, 0], [-1, 0]])
# deque([[-1, 0], [2, 1], [0, 1]])
#
# deque([[2, 1], [0, 1], [0, 1], [-2, 1]])
#
# deque([[0, 1], [0, 1], [-2, 1], [3, 2], [1, 2]])
#
# deque([[0, 1], [-2, 1], [3, 2], [1, 2], [1, 2], [-1, 2]])
#
# deque([[-2, 1], [3, 2], [1, 2], [1, 2], [-1, 2], [1, 2], [-1, 2]])
#
# deque([[3, 2], [1, 2], [1, 2], [-1, 2], [1, 2], [-1, 2], [-1, 2], [-3, 2]])
#
# deque([[1, 2], [1, 2], [-1, 2], [1, 2], [-1, 2], [-1, 2], [-3, 2], [4, 3], [2, 3]])
#
# deque([[1, 2], [-1, 2], [1, 2], [-1, 2], [-1, 2], [-3, 2], [4, 3], [2, 3], [2, 3], [0, 3]])
#
# deque([[-1, 2], [1, 2], [-1, 2], [-1, 2], [-3, 2], [4, 3], [2, 3], [2, 3], [0, 3], [2, 3], [0, 3]])
#
# deque([[1, 2], [-1, 2], [-1, 2], [-3, 2], [4, 3], [2, 3], [2, 3], [0, 3], [2, 3], [0, 3], [0, 3], [-2, 3]])
#
# deque([[-1, 2], [-1, 2], [-3, 2], [4, 3], [2, 3], [2, 3], [0, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [2, 3], [0, 3]])
#
# deque([[-1, 2], [-3, 2], [4, 3], [2, 3], [2, 3], [0, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3]])
#
# deque([[-3, 2], [4, 3], [2, 3], [2, 3], [0, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3]])
#
# deque([[4, 3], [2, 3], [2, 3], [0, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3]])
#
# deque([[2, 3], [2, 3], [0, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4]])
#
# deque([[2, 3], [0, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4]])
#
# deque([[0, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4]])
#
# deque([[2, 3], [0, 3], [0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4]])
#
# deque([[0, 3], [0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4]])
#
# deque([[0, 3], [-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4]])
#
# deque([[-2, 3], [2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4]])
#
# deque([[2, 3], [0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4]])
#
# deque([[0, 3], [0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4]])
#
# deque([[0, 3], [-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4]])
#
# deque([[-2, 3], [0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4]])
#
# deque([[0, 3], [-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4]])
#
# deque([[-2, 3], [-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4]])
#
# deque([[-2, 3], [-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4]])
#
# deque([[-4, 3], [5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4]])
#
# deque([[5, 4], [3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[3, 4], [3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[3, 4], [1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[3, 4], [1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-3, 4], [3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[3, 4], [1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-3, 4], [1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[1, 4], [-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-3, 4], [-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-1, 4], [-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-3, 4], [-3, 4], [-5, 4]])
#
# deque([[-3, 4], [-5, 4]])
#
# deque([[-5, 4]])
#
# deque([])
# 5

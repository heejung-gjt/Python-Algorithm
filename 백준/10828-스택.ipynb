# %%
# 시간초과


def push(arr,num):
    arr.append(num)
    return arr

def pop(arr):
    if len(arr)==0:
        print(-1)
    else:
        num = arr.pop(-1)
        print(num)
    return arr

def top(arr):
    if len(arr)==0:
        print(-1)
    else:
        print(arr[-1])
    
def size(arr):
    print(len(arr))

def empty(arr):
    if len(arr)==0:
        print(1)
    else:
        print(0)

arr = []
n = int(input())
for i in range(n):
    comm = input().split()
    if comm[0]=='push':
        arr = push(arr,comm[1])
    elif comm[0] == 'pop':
        arr = pop(arr);
    elif comm[0] =='top':
        top(arr)
    elif comm[0] =='size':
        size(arr)
    elif comm[0] =='empty':
        empty(arr)
# Out:
# 14
# push 1
# push 2
# top
# 2
# size
# 2
# empty
# 0
# pop
# 2
# pop
# 1
# pop
# -1
# size
# 0
# empty
# 1
# pop
# -1
# push 3
# empty
# 0
# top
# 3

# %%
# 시간 72ms


import sys


def push(num):
    return arr.append(num)

def pop():
    if not(arr):
        return -1
    else:
        return arr.pop()

def top():
    if not(arr):
        return -1
    else:
        return arr[-1]
    
def size():
    return len(arr)

def empty():
    if not(arr):
        return 1
    else:
        return 0

arr = []
n = int(sys.stdin.readline())
for i in range(n):
    comm = sys.stdin.readline().split()
    if comm[0]=='push':
        push(comm[1])
    elif comm[0] == 'pop':
        print(pop())
    elif comm[0] =='top':
        print(top())
    elif comm[0] =='size':
        print(size())
    elif comm[0] =='empty':
        print(empty())
